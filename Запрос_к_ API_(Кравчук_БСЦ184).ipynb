# %%
# !pip install --upgrade google-api-python-client
# !pip install --upgrade google-auth-oauthlib google-auth-httplib2

# %%
import googleapiclient.discovery as api
import pandas as pd

# %%
API_KEY = 'AIzaSyD7H6gBizWlsZkHerY3Hnka5us0KXYZvU4'
q = 'women in STEM'
type = 'channel'

# %%
api_service_name = 'youtube'
api_version = 'v3'
youtube = api.build(api_service_name, api_version, developerKey=API_KEY)

# %%
request = youtube.search().list(
    part = 'snippet',
    maxResults = 50, 
    q = q,
    type = type
)
response = request.execute()

# %%
response
# Out:
# {'etag': '1ldzjEEgqp93ZIU6YAaJcexhLGQ',
#  'items': [{'etag': 'W-7A7j7pQqTbb8B9VWcMhB2-JVo',
#    'id': {'channelId': 'UC1JUXQDOWP8rYsziWHIbOdw', 'kind': 'youtube#channel'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UC1JUXQDOWP8rYsziWHIbOdw',
#     'channelTitle': 'Women in STEM',
#     'description': 'We are the University of Colorado Anschutz Medical Campus Women in STEM Group. Welcome to our channel!',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-09-17T22:06:23Z',
#     'publishedAt': '2020-09-17T22:06:23Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AKedOLSvQSMHvzQm1cXb2822F4aK3AanW6erRWgUkl74=s88-c-k-c0xffffffff-no-rj-mo'},
#      'high': {'url': 'https://yt3.ggpht.com/ytc/AKedOLSvQSMHvzQm1cXb2822F4aK3AanW6erRWgUkl74=s800-c-k-c0xffffffff-no-rj-mo'},
#      'medium': {'url': 'https://yt3.ggpht.com/ytc/AKedOLSvQSMHvzQm1cXb2822F4aK3AanW6erRWgUkl74=s240-c-k-c0xffffffff-no-rj-mo'}},
# ...

# %%
display(response, '---', response.keys(), '---', response['pageInfo']['totalResults'])
# Out:
# {'etag': '1ldzjEEgqp93ZIU6YAaJcexhLGQ',
#  'items': [{'etag': 'W-7A7j7pQqTbb8B9VWcMhB2-JVo',
#    'id': {'channelId': 'UC1JUXQDOWP8rYsziWHIbOdw', 'kind': 'youtube#channel'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UC1JUXQDOWP8rYsziWHIbOdw',
#     'channelTitle': 'Women in STEM',
#     'description': 'We are the University of Colorado Anschutz Medical Campus Women in STEM Group. Welcome to our channel!',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-09-17T22:06:23Z',
#     'publishedAt': '2020-09-17T22:06:23Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AKedOLSvQSMHvzQm1cXb2822F4aK3AanW6erRWgUkl74=s88-c-k-c0xffffffff-no-rj-mo'},
#      'high': {'url': 'https://yt3.ggpht.com/ytc/AKedOLSvQSMHvzQm1cXb2822F4aK3AanW6erRWgUkl74=s800-c-k-c0xffffffff-no-rj-mo'},
#      'medium': {'url': 'https://yt3.ggpht.com/ytc/AKedOLSvQSMHvzQm1cXb2822F4aK3AanW6erRWgUkl74=s240-c-k-c0xffffffff-no-rj-mo'}},
# ...

# %%
df = pd.json_normalize(response['items'])

# %%
df
# Out:
#                     kind  ...   snippet.publishTime
# 0   youtube#searchResult  ...  2020-09-17T22:06:23Z
# 1   youtube#searchResult  ...  2017-08-02T06:50:18Z
# 2   youtube#searchResult  ...  2021-08-14T12:37:04Z
# 3   youtube#searchResult  ...  2019-08-10T00:17:02Z
# 4   youtube#searchResult  ...  2014-11-12T13:30:19Z
# 5   youtube#searchResult  ...  2021-05-11T00:06:09Z
# 6   youtube#searchResult  ...  2015-10-08T16:51:04Z
# 7   youtube#searchResult  ...  2019-05-18T15:53:15Z
# 8   youtube#searchResult  ...  2021-02-08T23:30:29Z
# 9   youtube#searchResult  ...  2021-04-21T16:41:56Z
# 10  youtube#searchResult  ...  2020-12-04T18:11:49Z
# 11  youtube#searchResult  ...  2017-08-18T14:02:30Z
# 12  youtube#searchResult  ...  2020-10-30T13:52:51Z
# 13  youtube#searchResult  ...  2017-12-07T18:17:00Z
# 14  youtube#searchResult  ...  2016-11-07T17:01:54Z
# 15  youtube#searchResult  ...  2021-10-31T22:43:13Z
# 16  youtube#searchResult  ...  2020-05-28T17:48:36Z
# ...

# %%
relevant_channels = df['snippet.channelTitle'].drop_duplicates().reset_index(drop=True)

# %%
relevant_channels
# Out:
# 0                                       Women in STEM
# 1                                       Women in Stem
# 2                                       women in stem
# 3                    Women in STEM: Breaking Barriers
# 4     Gotara: Global career network for women in STEM
# 5                                          STEM Women
# 6                               Women in STEM Society
# 7                                    EUWiSTEM Society
# 8                            Women in STEM Leadership
# 9                    Chicago Women in STEM Initiative
# 10                                          Dada STEM
# 11                               Pretty Smart Science
# 12                               Lauriann's STEM Club
# 13                             Women In STEM seminars
# 14         Novellety - Productivity For Women in STEM
# 15                               Women in Stem Africa
# 16                                   STEM Women on G+
# ...
