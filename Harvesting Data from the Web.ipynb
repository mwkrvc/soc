# %% [markdown]
# # Harvesting Data from the Web

# %% [markdown]
# One of the most common tasks in harvesting data is creating datasets from the information on the webpage. We will primarily work with the HSE page for the School of Sociology.

# %% [markdown]
# ## 1. Harvesting data on staff
#
# Go to this [page](https://social.hse.ru/en/soc/persons). Here you need to harvest the following information:
#
# 1. Names
# 2. Links to personal pages
# 3. Positions

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import re

# %%
url = "https://social.hse.ru/en/soc/persons"
page = requests.get(url)
soup = bs(page.text, "html.parser")
staff = soup.find_all("div", {"class": "fa-person__box"})

# %%
staff_list = {"name": [], "position": [], "url":[]}

# %%
for person in staff:
    staff_list["name"].append(person.find('a', class_='fa-person__name').text.strip())
    staff_list["position"].append(person.find('p', class_='fa-person__info').text.strip())
    staff_list["url"].append(person.find('a', class_='fa-person__name')['href'].replace('//', 'http://'))

# %%
df = pd.DataFrame.from_dict(staff_list)

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)
df
# Out:
#                            name                                     position  \
# 0            Lezhnina, Yulia P.                                         Head
# 1         Chepurenko, Alexander                          Academic Supervisor
# 2               Strebkov, Denis                           Deputy School Head
# 3               Zangieva, Irina                           Deputy School Head
# 4          Artamonova, Liudmila                                      Manager
# 5              Davidenko, Maria                          Assistant Professor
# 6            Davydov, Sergey G.                          Associate Professor
# 7                Di Puppo, Lili                          Assistant Professor
# 8           Fröhlich, Christian                          Associate Professor
# 9            Kuskova, Valentina                          Associate Professor
# 10               Manerova, Anna                                      Manager
# 11         Roy Chowdhury, Arnab                          Assistant Professor
# 12                Suh, Hyungjun                          Assistant Professor
# 13        Sсhmerling, Dmitry S.                           Research Professor
# 14               Gudkov, Lev D.                   Department Head, Professor
# 15           Fedorov, Valery V.                   Department Head, Professor
# 16            Deviatko, Inna F.                   Department Head, Professor
# 17               Abramov, Roman                                    Professor
# 18             Arslanova, Alina                            Visiting Lecturer
# 19        Bankovskaya, Svetlana                                    Professor
# 20                Bykov, Andrey                          Associate Professor
# 21               Kislenko, Ivan                            Visiting Lecturer
# 22              Klimov, Ivan A.                          Associate Professor
# 23            Klimova, Aigul M.                          Associate Professor
# 24               Korbut, Andrei                              Senior Lecturer
# 25             Kozhanov, Andrey                              Senior Lecturer
# 26           Ledyaev, Valery G.                                    Professor
# 27                  Mert, Ahmet                                     Lecturer
# 28           Nastina, Ekaterina                                     Lecturer
# 29      Rozhdestvenskaya, Elena                                    Professor
# 30          Sheremet, Elizaveta                                    Assistant
# 31            Varshaver, Evgeny                          Associate Professor
# 32            Pokrovsky, Nikita                   Professor, Department Head
# 33            Simonova, Olga A.                          Associate Professor
# 34        Antonova, Viktoria K.                                    Professor
# 35       Balabanova, Evgenia S.                                    Professor
# 36             Bogachev, Maksim                          Associate Professor
# 37               Efendiev, Azer                                    Professor
# 38         Gofman, Alexander B.                                    Professor
# 39               Gogoleva, Anna                          Associate Professor
# 40  Iarskaia-Smirnova, Elena R.                                    Professor
# 41            Kozlova, Maria A.                          Associate Professor
# 42               Logunova, Olga                          Associate Professor
# 43           Makarova, Xenia P.                            Visiting Lecturer
# 44                Mikheev, Igor                            Visiting Lecturer
# 45        Nikolaev, Vladimir G.                          Associate Professor
# 46                Popov, Dmitry                            Visiting Lecturer
# 47          Prisyazhniuk, Daria                              Senior Lecturer
# 48            Sadykov, Radik A.                            Visiting Lecturer
# 49               Sorvin, Kirill                          Associate Professor
# 50             Radaev, Vadim V.                   Department Head, Professor
# 51          Ibragimova, Dilyara  Deputy Department Head, Associate Professor
# 52             Asaturian, Daria                                     Lecturer
# 53          Barsukova, Svetlana                                    Professor
# 54           Bazhenova, Taisiya                            Visiting Lecturer
# 55            Berdysheva, Elena                          Associate Professor
# 56        Chepurenko, Alexander                                    Professor
# 57            Chernina, Evgenia                              Senior Lecturer
# 58              Conroy, Natalia                              Senior Lecturer
# 59              Demyanova, Anna                              Senior Lecturer
# 60             Gudova, Elena A.                              Senior Lecturer
# 61          Kazun, Anastasia D.                              Senior Lecturer
# 62                    Kim, Maya                            Visiting Lecturer
# 63        Kondratenko, Valeriya                                     Lecturer
# 64              Konovalov, Ilya                            Visiting Lecturer
# 65               Kosals, Leonid                                    Professor
# 66            Kotelnikova, Zoya                          Associate Professor
# 67               Kruglova, Anna                          Associate Professor
# 68        Kurakin, Alexander A.                              Senior Lecturer
# 69              Kuzina, Olga E.                                    Professor
# 70                Markin, Maxim                              Senior Lecturer
# 71      Nadezhdina, Evgeniya V.                          Associate Professor
# 72            Nazarbaeva, Elena                            Visiting Lecturer
# 73        Pashkov, Stanislav G.                                     Lecturer
# 74             Pavlyutkin, Ivan                          Associate Professor
# 75              Pishnyak, Alina                          Associate Professor
# 76           Poplavskaya, Anita                            Visiting Lecturer
# 77            Rebrov, Alexey V.                          Associate Professor
# 78              Roshchina, Yana                          Associate Professor
# 79             Shevchuk, Andrey                          Associate Professor
# 80              Strebkov, Denis                          Associate Professor
# 81                  Yudin, Greg                          Associate Professor
# 82      Bershadskaya, Margarita                                         Head
# 83        Artamonova, Marina V.                                      Analyst
#
#                                            url
# 0          http://www.hse.ru/en/staff/lezhnina
# 1       http://www.hse.ru/en/org/persons/63903
# 2          http://www.hse.ru/en/staff/strebkov
# 3     http://www.hse.ru/en/org/persons/7531133
# 4      http://www.hse.ru/en/org/persons/108084
# 5   http://www.hse.ru/en/org/persons/202139458
# 6     http://www.hse.ru/en/org/persons/8747291
# 7    http://www.hse.ru/en/org/persons/57316523
# 8   http://www.hse.ru/en/org/persons/127116556
# 9          http://www.hse.ru/en/staff/vkuskova
# 10  http://www.hse.ru/en/org/persons/221365535
# 11  http://www.hse.ru/en/org/persons/209454880
# 12  http://www.hse.ru/en/org/persons/426389983
# 13      http://www.hse.ru/en/org/persons/63808
# 14   http://www.hse.ru/en/org/persons/20272901
# 15   http://www.hse.ru/en/org/persons/18241277
# 16      http://www.hse.ru/en/org/persons/63717
# 17      http://www.hse.ru/en/org/persons/63703
# 18  http://www.hse.ru/en/org/persons/208486041
# 19     http://www.hse.ru/en/org/persons/228688
# 20   http://www.hse.ru/en/org/persons/42546046
# 21        http://www.hse.ru/en/staff/ikislenko
# 22      http://www.hse.ru/en/org/persons/63729
# 23          http://www.hse.ru/en/staff/klimova
# 24    http://www.hse.ru/en/org/persons/9017871
# 25        http://www.hse.ru/en/staff/akozhanov
# 26     http://www.hse.ru/en/org/persons/131782
# 27  http://www.hse.ru/en/org/persons/224291062
# 28  http://www.hse.ru/en/org/persons/208514747
# 29    http://www.hse.ru/en/org/persons/3979527
# 30        http://www.hse.ru/en/staff/esheremet
# 31   http://www.hse.ru/en/org/persons/27271079
# 32      http://www.hse.ru/en/org/persons/63830
# 33      http://www.hse.ru/en/org/persons/63823
# 34   http://www.hse.ru/en/org/persons/26157988
# 35    http://www.hse.ru/en/org/persons/3625966
# 36   http://www.hse.ru/en/org/persons/14250226
# 37      http://www.hse.ru/en/org/persons/61286
# 38      http://www.hse.ru/en/org/persons/63840
# 39     http://www.hse.ru/en/org/persons/414303
# 40    http://www.hse.ru/en/org/persons/4013457
# 41     http://www.hse.ru/en/org/persons/140047
# 42   http://www.hse.ru/en/org/persons/47633115
# 43    http://www.hse.ru/en/org/persons/4079427
# 44        http://www.hse.ru/en/staff/mikheevis
# 45      http://www.hse.ru/en/org/persons/63857
# 46     http://www.hse.ru/en/org/persons/140039
# 47   http://www.hse.ru/en/org/persons/12436422
# 48   http://www.hse.ru/en/org/persons/25923636
# 49      http://www.hse.ru/en/org/persons/63845
# 50      http://www.hse.ru/en/org/persons/63968
# 51    http://www.hse.ru/en/org/persons/3509413
# 52  http://www.hse.ru/en/staff/daria_asaturian
# 53       http://www.hse.ru/en/staff/sbarsukova
# 54        http://www.hse.ru/en/staff/bazhenova
# 55     http://www.hse.ru/en/org/persons/568425
# 56      http://www.hse.ru/en/org/persons/63903
# 57   http://www.hse.ru/en/org/persons/34617360
# 58   http://www.hse.ru/en/staff/natalia_conroy
# 59   http://www.hse.ru/en/org/persons/14259463
# 60           http://www.hse.ru/en/staff/gudova
# 61   http://www.hse.ru/en/org/persons/65821650
# 62  http://www.hse.ru/en/org/persons/208503054
# 63  http://www.hse.ru/en/org/persons/190894896
# 64  http://www.hse.ru/en/org/persons/210273777
# 65     http://www.hse.ru/en/org/persons/312256
# 66    http://www.hse.ru/en/org/persons/3509425
# 67  http://www.hse.ru/en/org/persons/195442997
# 68     http://www.hse.ru/en/org/persons/568698
# 69           http://www.hse.ru/en/staff/kuzina
# 70          http://www.hse.ru/en/staff/mmarkin
# 71      http://www.hse.ru/en/org/persons/63891
# 72   http://www.hse.ru/en/org/persons/10759370
# 73   http://www.hse.ru/en/org/persons/65841131
# 74     http://www.hse.ru/en/org/persons/260795
# 75      http://www.hse.ru/en/org/persons/63945
# 76   http://www.hse.ru/en/org/persons/25918622
# 77    http://www.hse.ru/en/org/persons/4013544
# 78     http://www.hse.ru/en/org/persons/188723
# 79         http://www.hse.ru/en/staff/shevchuk
# 80         http://www.hse.ru/en/staff/strebkov
# 81       http://www.hse.ru/en/staff/greg.yudin
# 82   http://www.hse.ru/en/org/persons/28206199
# 83     http://www.hse.ru/en/org/persons/108349

# %% [markdown]
# 1. How many people are there?
# 2. How many professors are there?
# 3. How many heads are there?
# 4. How many managers are there?

# %%
print("There are {} people".format(len(df)))
print("There are {} professors and {} professors who are also department heads".format(df['position'].value_counts()['Professor'], df['position'].value_counts()['Department Head, Professor']))
print("There are {} heads".format(df['position'].value_counts()['Head']))
print("There are {} managers".format(df['position'].value_counts()['Manager']))
# Out:
# There are 84 people
# There are 13 professors and 4 professors who are also department heads
# There are 2 heads
# There are 2 managers

# %% [markdown]
# ## 2. Harvesting data on each faculty member
#
# Now I want you to harvest the following information on each faculty staff:
#
# 1. What languages do they know?
# 2. What is their e-mail?
# 3. Do they have a link to a google scholar? If so, harvest this link
# 4. Do they teach any courses? If so, specify the names for these courses
# 5. How many publications do they have?

# %%
members = [x for x in df['url']]

# %%
import sys
check = 0
descr = {"name": [], "languages": [], "email":[], "GS": [], "courses": [], "pub_num": [], "lang_num": [], "course_num": []}
for iter, personal_url in enumerate(members):
    # check iteration number
    sys.stdout.write('\r'+'number of parsed pages: ' + str(iter) + '/' + str(len(df) - 1))
    sys.stdout.flush()
    personal_page = requests.get(personal_url)
    cold_soup = bs(personal_page.text, "html.parser")
    # name
    name = re.search(r'-(.*?)—', cold_soup.find('title').text).group(1)
    descr['name'].append(name)
    # number of publications
    pubs = cold_soup.find('ul', class_="g-ul g-list g-list_closer publications")
    num = 0
    if pubs is not None:
        for pub in pubs:
            num += 1
    else:
        num = 0
    descr['pub_num'].append(num)
    # mail
    mail = re.findall('\[.*-at-.*\]', cold_soup.prettify())[0].split('[')[1]
    mail_re = ''.join(map(str, re.findall(r'(-at-|[a-zA-Z]|\.+)', mail))).replace('-at-', '@')
    descr['email'].append(mail_re)
    # link to google scholar
    scholar = cold_soup.find('a', class_="link b")
    if scholar is not None:
        descr['GS'].append(scholar.get('href'))
    else:
        descr['GS'].append('No information')
    # languages
    languages = []
    nlang = 0
    for langs in cold_soup.find('dl').find_all('dd'):
        languages.append(langs.text)
        nlang += 1
    descr['languages'].append(' '.join(map(str, languages)))
    descr['lang_num'].append(nlang)
    # courses
    courses = cold_soup.find("div", {"tab-node": "edu-courses"})
    if courses is None:
        descr['courses'].append('No courses')
        descr['course_num'].append(0)
    else:
        cn = 0
        courses = courses.find('ul')
        if courses is None:
            courses = cold_soup.find("div", {"tab-node": "edu-courses"})
        list_of_courses = []
        for course in courses:
            if course.find('a') is not None:
                list_of_courses.append(course.find('a').text)
                cn += 1
        descr['courses'].append(' '.join(map(str, list_of_courses)))
        descr['course_num'].append(cn)
# Out:
# number of parsed pages: 83/83

# %%
df_descr = pd.DataFrame.from_dict(descr)
df_descr
# Out:
#                                   name  \
# 0                   Yulia P. Lezhnina
# 1                Alexander Chepurenko
# 2                      Denis Strebkov
# 3                      Irina Zangieva
# 4                 Liudmila Artamonova
# 5                     Maria Davidenko
# 6         Sergey Gennadyevich Davydov
# 7                       Lili Di Puppo
# 8                  Christian Fröhlich
# 9                   Valentina Kuskova
# 10                      Anna Manerova
# 11                Arnab Roy Chowdhury
# 12                       Hyungjun Suh
# 13               Dmitry S. Sсhmerling
# 14             Lev Dmitrievich Gudkov
# 15                  Valery V. Fedorov
# 16                   Inna F. Deviatko
# 17                      Roman Abramov
# 18                    Alina Arslanova
# 19               Svetlana Bankovskaya
# 20                       Andrey Bykov
# 21                      Ivan Kislenko
# 22          Ivan Alexandrovich Klimov
# 23                   Aigul M. Klimova
# 24                      Andrei Korbut
# 25                    Andrey Kozhanov
# 3. How many publications a faculty has on average?
# 4. Is there any difference between visiting lectures and and senior lectures?
# 5. Is there any difference between heads and others?
# 6. Is there any difference between professors and associate professors?

# %%
print("A faculty knows on average {} languages".format(df_descr['lang_num'].mean()))
print("A faculty has on average {} courses this year".format(df_descr['course_num'].mean()))
print("A faculty has on average {} publications".format(df_descr['pub_num'].mean()))
# Out:
# A faculty knows on average 1.7738095238095237 languages
# A faculty has on average 3.2738095238095237 courses this year
# A faculty has on average 22.55952380952381 publications

# %%
df_descr = pd.DataFrame.from_dict(descr)
df_descr['position'] = df['position']
df_descr['IsHead'] = df_descr['position'].str.contains('Head')
df_descr.groupby('IsHead').describe()
# Out:
#        pub_num                                                     lang_num  \
#          count       mean        std  min  25%   50%    75%    max    count
# IsHead
# False     74.0  20.662162  27.885420  0.0  3.0   6.0  31.75  157.0     74.0
# True      10.0  36.600000  43.050874  2.0  2.5  20.5  59.00  133.0     10.0
#
#                                                     course_num            \
#             mean       std  min  25%  50%  75%  max      count      mean
# IsHead
# False   1.743243  1.060638  1.0  1.0  1.0  2.0  6.0       74.0  3.364865
# True    2.000000  1.247219  1.0  1.0  2.0  2.0  5.0       10.0  2.600000
#
#
#              std  min   25%  50%  75%   max
# IsHead
# False   2.588565  0.0  1.25  3.0  5.0  14.0
# True    1.837873  0.0  1.25  2.0  4.5   5.0

# %%
test = df_descr.loc[(df_descr['position'] == 'Senior Lecturer') | (df['position'] == 'Visiting Lecturer')]
test.groupby('position').describe()
# Out:
#                   pub_num                                                     \
#                     count       mean        std  min  25%   50%    75%   max
# position
# Senior Lecturer      10.0  18.000000  20.231988  2.0  2.5  11.0  24.75  65.0
# Visiting Lecturer    11.0  11.090909  14.250997  0.0  0.0   3.0  21.50  36.0
#
#                   lang_num                                                \
#                      count      mean       std  min  25%  50%   75%  max
# position
# Senior Lecturer       10.0  1.300000  0.483046  1.0  1.0  1.0  1.75  2.0
# Visiting Lecturer     11.0  1.636364  0.809040  1.0  1.0  1.0  2.00  3.0
#
#                   course_num
#                        count      mean       std  min   25%  50%  75%  max
# position
# Senior Lecturer         10.0  2.700000  1.828782  1.0  1.25  2.5  3.0  7.0
# Visiting Lecturer       11.0  2.181818  1.990888  0.0  1.00  1.0  3.5  6.0

# %%
test1 = df_descr.loc[(df_descr['position'] == 'Associate Professor') | (df['position'] == 'Professor')]
test1.groupby('position').describe()
# Out:
#                     pub_num                                              \
#                       count       mean        std  min  25%   50%   75%
# position
# Associate Professor    25.0  34.400000  28.712657  0.0  6.0  32.0  52.0
# Professor              13.0  19.230769  42.464012  0.0  2.0   5.0   9.0
#
#                            lang_num                                          \
#                        max    count      mean       std  min  25%  50%  75%
# position
# Associate Professor  105.0     25.0  1.680000  0.945163  1.0  1.0  1.0  2.0
# Professor            157.0     13.0  1.769231  1.091928  1.0  1.0  1.0  3.0
#
#                          course_num                                          \
#                      max      count      mean       std  min  25%  50%  75%
# position
# Associate Professor  5.0       25.0  4.960000  3.102150  1.0  2.0  4.0  7.0
# Professor            4.0       13.0  3.923077  1.497862  2.0  3.0  4.0  5.0
#
#
#                       max
# position
# Associate Professor  14.0
# Professor             6.0
